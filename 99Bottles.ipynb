# %% [markdown]
# <a href="https://colab.research.google.com/github/noreallyimfine/hello-world/blob/master/99Bottles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Create a Python project that prints out every line of the song "99 bottles of (whatever you want) on the wall."
# #### Note: Try to use a built in function instead of manually type all the lines.

# %%
# Your code goes here
for i in range(99, 0, -1):
  print(f'''{i} bottles of kombucha on the wall, {i} bottles of kombucha,
            take one down pass it around {i-1} bottles of kombucha on the
            wall.''')
# Out:
# 99 bottles of kombucha on the wall, 99 bottles of kombucha,
#             take one down pass it around 98 bottles of kombucha on the
#             wall.
# 98 bottles of kombucha on the wall, 98 bottles of kombucha,
#             take one down pass it around 97 bottles of kombucha on the
#             wall.
# 97 bottles of kombucha on the wall, 97 bottles of kombucha,
#             take one down pass it around 96 bottles of kombucha on the
#             wall.
# 96 bottles of kombucha on the wall, 96 bottles of kombucha,
#             take one down pass it around 95 bottles of kombucha on the
#             wall.
# 95 bottles of kombucha on the wall, 95 bottles of kombucha,
#             take one down pass it around 94 bottles of kombucha on the
#             wall.
# 94 bottles of kombucha on the wall, 94 bottles of kombucha,
#             take one down pass it around 93 bottles of kombucha on the
#             wall.
# 93 bottles of kombucha on the wall, 93 bottles of kombucha,
# ...
